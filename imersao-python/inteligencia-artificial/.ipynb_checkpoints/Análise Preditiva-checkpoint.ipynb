# %% [markdown]
# ## Carregar dados das ações

# %%
import yfinance as yf

# %%
ticker = input("Digite o código da ação: ")
dados = yf.Ticker(ticker).history("2y")
dados.head()
# Out:
# Digite o código da ação: BBAS3.SA
#                                 Open       High        Low      Close  \
# Date
# 2021-06-02 00:00:00-03:00  29.143133  30.326347  29.117408  30.180590
# 2021-06-04 00:00:00-03:00  30.009108  30.729327  29.949090  30.652161
# 2021-06-07 00:00:00-03:00  30.669314  31.509569  30.437815  31.312366
# 2021-06-08 00:00:00-03:00  31.209482  31.440978  30.669317  31.123739
# 2021-06-09 00:00:00-03:00  31.037998  31.175182  29.991965  30.523554
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-06-02 00:00:00-03:00  26347900        0.0           0.0
# 2021-06-04 00:00:00-03:00  13927500        0.0           0.0
# 2021-06-07 00:00:00-03:00  21783200        0.0           0.0
# 2021-06-08 00:00:00-03:00  20839000        0.0           0.0
# 2021-06-09 00:00:00-03:00  21292700        0.0           0.0

# %%
dados["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Tratamento de dados
